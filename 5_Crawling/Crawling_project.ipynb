# %% [markdown]
# #### Crawling project
#     - 잡코리아 크롤링은 통한 고용시장 분석

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen 
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import koreanize_matplotlib
import pandas as pd
import time
import numpy as np
from PIL import Image
from matplotlib.patches import ConnectionPatch
from crawling_funtion import *

# %%
link_list, cor_title_list= get_links()

# %%
#채용공고내 스킬 및 기업정보 링크 크롤링
skill_list, cor_link_list= get_skill(link_list)
print(cor_link_list)

# %%
# 연봉정보 크롤링
    # 1. 연봉정보 링크 크롤링
salary_link_list= get_salary_links(cor_link_list)
    # 2. 연봉정보 크롤링
salary_list= get_salary_info(salary_link_list)

# %%
# 공고 지역 크롤링
loc_list= get_loc(recuit_link_list)

# %% [markdown]
# ------------------------------------------------------------------

# %% [markdown]
# #### 시각화

# %%
## 지역별 공고 수 시각화
    # 지역별 구인공고 분류
DF= pd.read_csv('지역정보.csv')
DF.drop(columns=['Unnamed: 0'], inplace=True)
DF_list= (DF['지역'])
seoul, busan, inchan, daegu, changju, gyunggi = 0,0,0,0,0,0
other=5
for list in DF_list:
    if ('서울') in list:
        seoul+=1 
    if ('경기') in list:
        gyunggi+=1
    if ('부산') in list:
        busan+=1 
    if ('대구') in list:
        daegu+=1
    if ('인천') in list: 
        inchan+=1 
    if ('충청북') in list:
        changju+=1

    # 시각화를 위해 리스트에 담기
pie_data_list=[busan+daegu+other, gyunggi, seoul]
sum_num=(busan+daegu+other)
bar_data_list=[busan/sum_num, daegu/sum_num, other/sum_num]
label_list=['그외', '경기','서울']

# %%
#파이그래프 그리기 (matplotlib 예시코드 참조)

fig, (ax1, ax2)= plt.subplots(1, 2, figsize=(9,5))
fig.subplots_adjust(wspace=0)

#pie그리기
overall_ratios = pie_data_list
labels = label_list
explode = [0.1, 0, 0]
# 적은 비율이 오른쪽으로 향하도록 조정
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.2f%%', startangle=angle,
                     labels=labels, explode=explode, colors=['#4374D9', '#47C83E', '#E9537C' ])

# bar 그리기
age_ratios = bar_data_list
age_labels = ['부산', '대구', '기타']
bottom = 1
width = .2

# 그외의 범주 추가
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('서울&경기 외')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# 파이차트와 막대그래프를 잇는 선 그리기
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# 위쪽 선 그리기
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# 아래쪽 선 그리기
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)
plt.suptitle('지역별 채용공고 현황')

plt.show()

# %%
# 연봉 정보 시각화
DF=pd.read_csv('./연봉정보.csv')
DF.drop(columns=['Unnamed: 0'], inplace=True)
print(DF.info())

plt.hist(DF, bins=20, histtype='bar')
plt.xlabel='연봉(만원)'
plt.title('직원들의 연봉 범위')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       298 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB
# None

# %%
#스킬 정보 시각화
title_list= pd.read_csv('스킬정보.csv')['0']

word_count=50
stopwords=['python', 'Python']
path= r'c:\Windows\Fonts\malgun.ttf'
def make_skill_gragh():

    okt= Okt()
    sentences_tag= []

    for sentence in title_list:
        morph= okt.pos(sentence)
        sentences_tag.append(morph)
        print(morph)
        print('-'*80)
    
    noun_adj_list=[]
    for sentence1 in sentences_tag:
        for word, tag in sentence1:
            if tag in ['Noun', 'Adjective', 'Alpha']:
                noun_adj_list.append(word)

    counts= Counter(noun_adj_list)
    tags= counts.most_common(word_count)
    print('-'*80)
    print(tags)

    tag_dict= dict(tags)

    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
    print(tag_dict)

    img_mask= np.array(Image.open('alice_wordcloud.png'))
    wordcloud= WordCloud(font_path=path, width=800, height=600,
    background_color='white', max_font_size=200,
    repeat=True,
    colormap='inferno', mask=img_mask)
        
    cloud= wordcloud.generate_from_frequencies(tag_dict)
    plt.figure(figsize=(10,8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()
make_skill_gragh()
# Out:
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Node', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('R', 'Alpha')]
# --------------------------------------------------------------------------------
# [('건설', 'Noun'), ('안전', 'Noun'), ('기사', 'Noun'), ('자격', 'Noun')]
# --------------------------------------------------------------------------------
# [('건설', 'Noun'), ('안전', 'Noun'), ('산업', 'Noun'), ('기사', 'Noun'), ('자격', 'Noun')]
# --------------------------------------------------------------------------------
# [('산업', 'Noun'), ('안전', 'Noun'), ('기사', 'Noun'), ('자격', 'Noun')]
# --------------------------------------------------------------------------------
# [('산업', 'Noun'), ('안전', 'Noun'), ('산업', 'Noun'), ('기사', 'Noun'), ('자격', 'Noun')]
# --------------------------------------------------------------------------------
# [('.', 'Punctuation'), ('Net', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DB', 'Alpha'), ('2', 'Number')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JSP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MSSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Oracle', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Ai', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Chatbot', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Langchain', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PostgreSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Fastapi', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Kafka', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha'), ('Framework', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('React', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ROS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pandas', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('R', 'Alpha'), ('처리', 'Noun')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Linux', 'Alpha')]
# --------------------------------------------------------------------------------
# [('FTP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('GUI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Serial', 'Alpha')]
# --------------------------------------------------------------------------------
# [('TCP', 'Alpha'), ('/', 'Punctuation'), ('IP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Kafka', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Fastapi', 'Alpha')]
# --------------------------------------------------------------------------------
# [('celery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQLAlchemy', 'Alpha'), ('ORM', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Hdoop', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Jira', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MSSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PostgreSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Ubuntu', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Fastapi', 'Alpha')]
# --------------------------------------------------------------------------------
# [('GithubAction', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Svelte', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Linux', 'Alpha')]
# --------------------------------------------------------------------------------
# [('FTP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('GUI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Serial', 'Alpha')]
# --------------------------------------------------------------------------------
# [('TCP', 'Alpha'), ('/', 'Punctuation'), ('IP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Ubuntu', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CSS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('React', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RestAPI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Restful', 'Alpha'), ('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Node', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha'), ('-', 'Punctuation'), ('BackEnd', 'Alpha'), ('개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('React', 'Alpha'), ('-', 'Punctuation'), ('FrontEnd', 'Alpha'), ('개발', 'Noun')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha'), ('&', 'Punctuation'), ('AWS', 'Alpha'), ('경험', 'Noun'), ('자', 'Suffix')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('TCP', 'Alpha'), ('/', 'Punctuation'), ('IP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('TCP', 'Alpha'), ('/', 'Punctuation'), ('IP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PostgreSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MarinDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('vue', 'Alpha'), ('또는', 'Adverb'), ('React', 'Alpha'), ('개발', 'Noun'), ('가능', 'Noun'), ('자', 'Suffix'), ('(', 'Punctuation'), ('필수', 'Noun'), (')', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Keras', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('전자정부', 'Noun'), ('표준', 'Noun'), ('프레임워크', 'Noun')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Flask', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Fastapi', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Streamlit', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Web', 'Alpha'), ('Application', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Flutter', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQLD', 'Alpha'), ('자격', 'Noun')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha'), ('5', 'Number')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('GCP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('TerraForm', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha'), ('Boot', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ETL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('bash', 'Alpha'), ('shell', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CSS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Flask', 'Alpha')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('.', 'Punctuation'), ('Net', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Android', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ASP.NET', 'URL')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('iOS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ASP.NET', 'URL')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MiPlatform', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Oracle', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('영어', 'Noun')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MongoDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Node', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('도장', 'Noun')]
# --------------------------------------------------------------------------------
# [('생산', 'Noun')]
# --------------------------------------------------------------------------------
# [('제작', 'Noun')]
# --------------------------------------------------------------------------------
# [('도면', 'Noun')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PHP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('풀', 'Noun'), ('스택', 'Noun')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('React', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha'), ('Boot', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('GitLab', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Restful', 'Alpha'), ('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('TDD', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DRF', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Node', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('NoSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha'), ('Boot', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Fastapi', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CSS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Jquery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('OpenCV', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('R', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Ai', 'Alpha')]
# --------------------------------------------------------------------------------
# [('KDT', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Google', 'Alpha'), ('Analytics', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tableau', 'Alpha')]
# --------------------------------------------------------------------------------
# [('POWER', 'Alpha'), ('BI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('pyton', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Android', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PHP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Linux', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MongoDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('파이썬', 'Noun')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MongoDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('TypeScript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Nest', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ORM', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Google', 'Alpha'), ('Analytics', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RPA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Linux', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RestAPI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha'), ('Boot', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Oracle', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Shell', 'Alpha'), ('Script', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RestAPI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('WebSocket', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Fastapi', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CAN', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CANoe', 'Alpha')]
# --------------------------------------------------------------------------------
# [('오실로스코프', 'Noun')]
# --------------------------------------------------------------------------------
# [('CAPL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Bootstrap', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Jquery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('React', 'Alpha')]
# --------------------------------------------------------------------------------
# [('풀', 'Noun'), ('스택', 'Noun')]
# --------------------------------------------------------------------------------
# [('Restful', 'Alpha'), ('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Kafka', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Fastapi', 'Alpha')]
# --------------------------------------------------------------------------------
# [('iOS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MacOS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('OracleDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('OpenCV', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('NLP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('yolo', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RestAPI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Vue', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Keras', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('전자정부', 'Noun'), ('표준', 'Noun'), ('프레임워크', 'Noun')]
# --------------------------------------------------------------------------------
# [('.', 'Punctuation'), ('Net', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('OracleDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PL', 'Alpha'), ('/', 'Punctuation'), ('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AR', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Excel', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PowerPoint', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('프로그래밍', 'Noun')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MSA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CSS', 'Alpha'), ('3', 'Number')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha'), ('5', 'Number')]
# --------------------------------------------------------------------------------
# [('Jquery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('풀', 'Noun'), ('스택', 'Noun')]
# --------------------------------------------------------------------------------
# [('Bootstrap', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CSS', 'Alpha'), ('3', 'Number')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Jquery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JSP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pandas', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('React', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Servlet', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ERP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('무역영어', 'Noun')]
# --------------------------------------------------------------------------------
# [('GitHub', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Matplotlib', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Numpy', 'Alpha')]
# --------------------------------------------------------------------------------
# [('국제', 'Noun'), ('무역사', 'Noun'), ('자격', 'Noun')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('크롤', 'Noun'), ('링', 'Noun')]
# --------------------------------------------------------------------------------
# [('스크', 'Noun'), ('래핑', 'Noun')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('#', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Linux', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JSP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('OracleDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('풀', 'Noun'), ('스택', 'Noun')]
# --------------------------------------------------------------------------------
# [('Cloud', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Flask', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('React', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RestAPI', 'Alpha')]
# ...
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('/', 'Punctuation'), ('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('기계설계', 'Noun')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ROS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SLAM', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SVM', 'Alpha')]
# --------------------------------------------------------------------------------
# [('자율', 'Noun'), ('주행', 'Noun')]
# --------------------------------------------------------------------------------
# [('RMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('영어', 'Noun')]
# --------------------------------------------------------------------------------
# [('Ajax', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CSS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ECMAscript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Git', 'Alpha')]
# --------------------------------------------------------------------------------
# [('HTML', 'Alpha'), ('5', 'Number')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Node', 'Alpha'), ('.', 'Punctuation'), ('js', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PHP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Svg', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MSSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Oracle', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('R', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SAS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CRScube', 'Alpha')]
# --------------------------------------------------------------------------------
# [('medidata', 'Alpha')]
# --------------------------------------------------------------------------------
# [('stat', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('DBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Django', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pandas', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ETL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spark', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Jquery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Jquery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MSSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Oracle', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PostgreSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RestAPI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Spring', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('EAI', 'Alpha')]
# --------------------------------------------------------------------------------
# [('ETL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SOAP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Restful', 'Alpha'), ('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('OpenCV', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Vision', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('kubernetes', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MSA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PostgreSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Redis', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Linux', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Rabbit', 'Alpha'), ('MQ', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Restful', 'Alpha'), ('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('JAVA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MySQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PHP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('공인', 'Noun'), ('중개사', 'Noun'), ('자격', 'Noun')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('보안', 'Noun'), ('엔지니어', 'Noun')]
# --------------------------------------------------------------------------------
# [('OpenCV', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Matplotlib', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Seaborn', 'Alpha')]
# --------------------------------------------------------------------------------
# [('plotly', 'Alpha')]
# --------------------------------------------------------------------------------
# [('API', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Javascript', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Jquery', 'Alpha')]
# --------------------------------------------------------------------------------
# [('MariaDB', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PHP', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha')]
# --------------------------------------------------------------------------------
# [('C', 'Alpha'), ('++', 'Punctuation')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('CUDA', 'Alpha')]
# --------------------------------------------------------------------------------
# [('LiDAR', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Docker', 'Alpha')]
# --------------------------------------------------------------------------------
# [('NoSQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('RDBMS', 'Alpha')]
# --------------------------------------------------------------------------------
# [('plotly', 'Alpha')]
# --------------------------------------------------------------------------------
# [('AWS', 'Alpha'), ('codecommit', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pandas', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Python', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Pytorch', 'Alpha')]
# --------------------------------------------------------------------------------
# [('SQL', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Tensorflow', 'Alpha')]
# --------------------------------------------------------------------------------
# [('PyQt', 'Alpha')]
# --------------------------------------------------------------------------------
# [('Scikit', 'Alpha'), ('-', 'Punctuation'), ('Learn', 'Alpha')]
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# [('Python', 282), ('C', 139), ('JAVA', 113), ('AWS', 75), ('SQL', 62), ('Linux', 49), ('API', 45), ('Spring', 44), ('MySQL', 42), ('Docker', 37), ('js', 36), ('Git', 31), ('Javascript', 30), ('Pytorch', 28), ('React', 28), ('Tensorflow', 25), ('kubernetes', 21), ('Django', 19), ('Node', 18), ('R', 18), ('Boot', 18), ('PostgreSQL', 17), ('RDBMS', 17), ('HTML', 17), ('영어', 17), ('MariaDB', 16), ('PHP', 16), ('자격', 15), ('MSSQL', 14), ('Oracle', 14), ('Vue', 13), ('CSS', 12), ('RestAPI', 12), ('Kafka', 11), ('MongoDB', 11), ('Tableau', 11), ('Net', 10), ('풀', 10), ('스택', 10), ('OpenCV', 10), ('Ai', 9), ('Fastapi', 9), ('Restful', 9), ('Android', 9), ('NoSQL', 9), ('Shell', 9), ('Script', 9), ('Excel', 9), ('ml', 9), ('Matlab', 9)]
# {'C': 139, 'JAVA': 113, 'AWS': 75, 'SQL': 62, 'Linux': 49, 'API': 45, 'Spring': 44, 'MySQL': 42, 'Docker': 37, 'js': 36, 'Git': 31, 'Javascript': 30, 'Pytorch': 28, 'React': 28, 'Tensorflow': 25, 'kubernetes': 21, 'Django': 19, 'Node': 18, 'R': 18, 'Boot': 18, 'PostgreSQL': 17, 'RDBMS': 17, 'HTML': 17, '영어': 17, 'MariaDB': 16, 'PHP': 16, '자격': 15, 'MSSQL': 14, 'Oracle': 14, 'Vue': 13, 'CSS': 12, 'RestAPI': 12, 'Kafka': 11, 'MongoDB': 11, 'Tableau': 11, 'Net': 10, '풀': 10, '스택': 10, 'OpenCV': 10, 'Ai': 9, 'Fastapi': 9, 'Restful': 9, 'Android': 9, 'NoSQL': 9, 'Shell': 9, 'Script': 9, 'Excel': 9, 'ml': 9, 'Matlab': 9}

# %%
# 블로그 워드클라우드
import requests
    # 블로그 크롤링 함수
def get_titles(start_num, end_num, search_word, title_list):
    while start_num <= end_num:
        url= ('https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query={}&start={}'.format(search_word, start_num))

        req= requests.get(url)
        time.sleep(1)
        if req.ok:
            soup= BeautifulSoup(req.text, 'html.parser')
            news_titles= soup.find_all('div', {'class': 'title_area'})
            for news in news_titles:
                title_list.append(news.text)
        start_num+=10
        print('title 개수:', len(title_list))
        print(title_list)
    # 시각화 함수
def make_wordcloud(title_list, stopwords, word_count):
    okt= Okt()
    sentences_tag= []

    for sentence in title_list:
        morph= okt.pos(sentence)
        sentences_tag.append(morph)
        print(morph)
        print('-'*80)
    
    noun_adj_list=[]
    for sentence1 in sentences_tag:
        for word, tag in sentence1:
            if tag in ['Noun', 'Adjective', 'Alpha']:
                noun_adj_list.append(word)

    counts= Counter(noun_adj_list)
    tags= counts.most_common(word_count)
    print('-'*80)
    print(tags)

    tag_dict= dict(tags)

    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
    print(tag_dict)

    path= r'c:\Windows\Fonts\malgun.ttf'

    img_mask= np.array(Image.open('P.jfif'))
    wordcloud= WordCloud(font_path=path, width=800, height=600,
                         background_color='white', max_font_size=200,
                         repeat=True,
                         colormap='inferno', mask=img_mask)
    
    cloud= wordcloud.generate_from_frequencies(tag_dict)
    plt.figure(figsize=(10,8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()

# %%
# 함수 실행

search_word= '파이썬'
title_list=[]
stopwords= [search_word, 'python', 'Python', '코딩', '아나콘다', '설치', '프로그래밍']

get_titles(1, 200, search_word, title_list)

make_wordcloud(title_list, stopwords, 50)
